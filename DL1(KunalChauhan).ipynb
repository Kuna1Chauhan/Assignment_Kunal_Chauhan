# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Load the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalize pixel values to the range of 0 and 1
X_train = X_train / 255.0
X_test = X_test / 255.0

# Reshape the input data to have a single channel (grayscale)
X_train = X_train.reshape((-1, 28, 28, 1))
X_test = X_test.reshape((-1, 28, 28, 1))

# Define a function to create a CNN model
def create_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(10, activation='softmax'))
    return model

# Define the first CNN architecture
model1 = create_model()
model1.summary()

# Compile and train the model
model1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model1.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Define the second CNN architecture
model2 = create_model()
model2.summary()

# Compile and train the model
model2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model2.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Define the third CNN architecture
model3 = create_model()
model3.summary()

# Compile and train the model
model3.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model3.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the models
accuracy1 = model1.evaluate(X_test, y_test)[1]
accuracy2 = model2.evaluate(X_test, y_test)[1]
accuracy3 = model3.evaluate(X_test, y_test)[1]

# Create a comparison table
table = pd.DataFrame({'Model': ['Model 1', 'Model 2', 'Model 3'],
                      'Accuracy': [accuracy1, accuracy2, accuracy3]})

print(table)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  flatten (Flatten)           (None, 5408)              0
#
#  dense (Dense)               (None, 64)                346176
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 347,146
# Trainable params: 347,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.1816 - accuracy: 0.9468 - val_loss: 0.0718 - val_accuracy: 0.9771
# Epoch 2/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0617 - accuracy: 0.9812 - val_loss: 0.0510 - val_accuracy: 0.9826
# Epoch 3/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0422 - accuracy: 0.9870 - val_loss: 0.0557 - val_accuracy: 0.9827
# Epoch 4/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0305 - accuracy: 0.9906 - val_loss: 0.0440 - val_accuracy: 0.9856
# Epoch 5/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0225 - accuracy: 0.9927 - val_loss: 0.0446 - val_accuracy: 0.9859
# Epoch 6/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.0169 - accuracy: 0.9943 - val_loss: 0.0482 - val_accuracy: 0.9856
# Epoch 7/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.0492 - val_accuracy: 0.9850
# Epoch 8/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0094 - accuracy: 0.9971 - val_loss: 0.0395 - val_accuracy: 0.9875
# Epoch 9/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.0491 - val_accuracy: 0.9883
# Epoch 10/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0551 - val_accuracy: 0.9864
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 5408)              0
#
#  dense_2 (Dense)             (None, 64)                346176
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 347,146
# Trainable params: 347,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 39s 21ms/step - loss: 0.1852 - accuracy: 0.9464 - val_loss: 0.0688 - val_accuracy: 0.9781
# Epoch 2/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0627 - accuracy: 0.9810 - val_loss: 0.0553 - val_accuracy: 0.9811
# Epoch 3/10
# 1875/1875 [==============================] - 39s 21ms/step - loss: 0.0433 - accuracy: 0.9868 - val_loss: 0.0433 - val_accuracy: 0.9858
# Epoch 4/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0298 - accuracy: 0.9904 - val_loss: 0.0432 - val_accuracy: 0.9856
# Epoch 5/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.0231 - accuracy: 0.9930 - val_loss: 0.0481 - val_accuracy: 0.9846
# Epoch 6/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0164 - accuracy: 0.9946 - val_loss: 0.0469 - val_accuracy: 0.9857
# Epoch 7/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0117 - accuracy: 0.9961 - val_loss: 0.0582 - val_accuracy: 0.9840
# Epoch 8/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.0101 - accuracy: 0.9964 - val_loss: 0.0554 - val_accuracy: 0.9848
# Epoch 9/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 0.0628 - val_accuracy: 0.9845
# Epoch 10/10
# 1875/1875 [==============================] - 39s 21ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.0611 - val_accuracy: 0.9851
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 5408)              0
#
#  dense_4 (Dense)             (None, 64)                346176
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 347,146
# Trainable params: 347,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.1649 - accuracy: 0.9517 - val_loss: 0.0631 - val_accuracy: 0.9789
# Epoch 2/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0581 - accuracy: 0.9816 - val_loss: 0.0545 - val_accuracy: 0.9814
# Epoch 3/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.0397 - accuracy: 0.9875 - val_loss: 0.0538 - val_accuracy: 0.9825
# Epoch 4/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0275 - accuracy: 0.9918 - val_loss: 0.0519 - val_accuracy: 0.9831
# Epoch 5/10
# 1875/1875 [==============================] - 39s 21ms/step - loss: 0.0209 - accuracy: 0.9936 - val_loss: 0.0504 - val_accuracy: 0.9850
# Epoch 6/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0150 - accuracy: 0.9952 - val_loss: 0.0482 - val_accuracy: 0.9861
# Epoch 7/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0111 - accuracy: 0.9966 - val_loss: 0.0581 - val_accuracy: 0.9859
# Epoch 8/10
# 1875/1875 [==============================] - 39s 21ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0490 - val_accuracy: 0.9860
# Epoch 9/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0068 - accuracy: 0.9977 - val_loss: 0.0535 - val_accuracy: 0.9866
# Epoch 10/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.0499 - val_accuracy: 0.9870
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0551 - accuracy: 0.9864
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0611 - accuracy: 0.9851
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0499 - accuracy: 0.9870
#      Model  Accuracy
# 0  Model 1    0.9864
# 1  Model 2    0.9851
# 2  Model 3    0.9870
